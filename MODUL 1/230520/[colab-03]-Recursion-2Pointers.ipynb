# %%
# aivietnam

def sum_list(arr):
    total = 0
    n = len(arr)
    for i in range(n):
        total = total + arr[i]
    return total

arr = [1, 2, 1, 5, 3]
sum_list(arr)
# Out:
# 12

# %%
# aivietnam

def sum_recursion(arr):
    if arr == []:
        return 0
    else:
        smaller_problem = arr[1:]
        smaller_result = sum_recursion(smaller_problem)
        return arr[0] + smaller_result

arr = [1, 2, 1, 5, 3]
sum_recursion(arr)
# Out:
# 12

# %%
# aivietnam

def factorial(n):
    if n == 0:
        return 1
    else:
        smaller_fac = n-1
        smaller_res = factorial(smaller_fac)
        return n * smaller_res

n = 4
factorial(n)
# Out:
# 24

# %%
# aivietnam

def fibonacci(n):
    # base case
    if n == 0:
        return 0
    elif n == 1:
        return 1
    # recursive func
    else:
        return fibonacci(n-1) + fibonacci(n-2)

n = 4
fibonacci(n)
# Out:
# 3

# %%
#aivietnam

arr = [1, 2, 1, 5, 3]
print(arr[0], arr[-5])
print(arr[1], arr[-4])
print(arr[4], arr[-1])
# Out:
# 1 1
# 2 2
# 3 3

# %%
# aivietnam

def reverse_str_using_for(s):
    tg_s = ''
    n = len(s)
    for i in range(n-1, -1, -1):
        tg_s += s[i]
    return tg_s

s = 'hello'
print(reverse_str_using_for(s))
s = 'Hannah'
print(reverse_str_using_for(s))
# Out:
# olleh
# hannaH

# %%
# aivietnam

def reverse_str_two_pointers(s):
    s = list(s)
    i = 0
    j = len(s) - 1
    while i < j:
        s[i], s[j] = s[j], s[i]
        i = i + 1
        j = j - 1
    return "".join(s)

s = 'hello'
print(reverse_str_two_pointers(s))
s = 'Hannah'
print(reverse_str_two_pointers(s))
# Out:
# olleh
# hannaH

# %%
# aivietnam

def subarray_sum(nums, key):
        n = len(nums)
        count = 0
        for i in range(n):
            total = 0
            for j in range(i, n):
                total += nums[j]
                if total == key:
                    count += 1
        return count


nums = [1, 2, 3, 5, 6]
key = 5
subarray_sum(nums, key)
# Out:
# 2

# %%
#aivietnam

def subarray_sum_two_pointer(nums, key):
    i = 0
    j = 0
    count = 0
    total = 0
    n = len(nums)
    while (i < n) and (j < n):
        if total + nums[i] < key:
            total += nums[i]
            i += 1
        elif total + nums[i] > key:
            total -= nums[j]
            j += 1
        else:
            count += 1
            total += nums[i]
            i += 1
    return count

nums = [1, 2, 3, 5, 6]
key = 5
subarray_sum_two_pointer(nums, key)
# Out:
# 2
